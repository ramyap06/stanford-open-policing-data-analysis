# %%
import polars as pl
import matplotlib.pyplot as plt
file_path = r'C:\Users\ramya\Downloads\openpolicing.parquet'
lf = pl.scan_parquet(file_path)

# %%
lf.limit(50).collect()
# Out:
# shape: (50, 67)
# ┌────────────┬──────────┬──────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ date       ┆ time     ┆ location ┆ county_na ┆ … ┆ use_of_fo ┆ charged_s ┆ subdivisi ┆ substatio │
# │ ---        ┆ ---      ┆ ---      ┆ me        ┆   ┆ rce_reaso ┆ peed      ┆ on        ┆ n         │
# │ date       ┆ str      ┆ str      ┆ ---       ┆   ┆ n         ┆ ---       ┆ ---       ┆ ---       │
# │            ┆          ┆          ┆ str       ┆   ┆ ---       ┆ str       ┆ str       ┆ str       │
# │            ┆          ┆          ┆           ┆   ┆ str       ┆           ┆           ┆           │
# ╞════════════╪══════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2000-01-06 ┆ 23:25:00 ┆ Unknown  ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │ 2000-01-06 ┆ 23:55:00 ┆ Unknown  ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │ 2000-01-06 ┆ 21:36:00 ┆ Unknown  ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │ 2000-01-07 ┆ 02:30:00 ┆ Unknown  ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │ 2000-01-07 ┆ 04:15:00 ┆ Unknown  ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │ …          ┆ …        ┆ …        ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2000-01-12 ┆ 16:00:00 ┆ Unknown  ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │ 2000-01-12 ┆ 15:55:00 ┆ Unknown  ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │ 2000-01-12 ┆ 10:20:00 ┆ Unknown  ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │ 2000-01-13 ┆ 23:36:00 ┆ Unknown  ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# │ 2000-01-14 ┆ 01:50:00 ┆ Unknown  ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# └────────────┴──────────┴──────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
columns = list(lf.schema.keys())
columns
# Out:
# C:\Users\ramya\AppData\Local\Temp\ipykernel_15704\3417325164.py:1: PerformanceWarning: Resolving the schema of a LazyFrame is a potentially expensive operation. Use `LazyFrame.collect_schema()` to get the schema without this warning.
#   columns = list(lf.schema.keys())
# ['date',
#  'time',
#  'location',
#  'county_name',
#  'subject_age',
#  'subject_race',
#  'subject_sex',
#  'officer_id_hash',
#  'department_name',
#  'type',
#  'arrest_made',
#  'citation_issued',
#  'warning_issued',
#  'outcome',
#  'contraband_found',
#  'contraband_drugs',
#  'contraband_weapons',
#  'frisk_performed',
#  'search_conducted',
#  'search_person',
#  'search_vehicle',
#  'search_basis',
#  'reason_for_frisk',
#  'reason_for_search',
#  'reason_for_stop',
#  'violation',
#  'vehicle_color',
#  'vehicle_make',
#  'vehicle_model',
#  'vehicle_registration_state',
#  'vehicle_year',
#  'service_area',
#  'officer_race',
#  'lat',
#  'lng',
#  'geocode_source',
#  'beat',
#  'division',
#  'officer_sex',
#  'disposition',
#  'posted_speed',
#  'district',
#  'precinct',
#  'speed',
#  'contraband_other',
#  'vehicle_type',
#  'officer_age',
#  'officer_years_of_service',
#  'unit',
#  'notes',
#  'sector',
#  'subsector',
#  'officer_assignment',
#  'use_of_force_description',
#  'department_id',
#  'contraband_alcohol',
#  'zone',
#  'region',
#  'neighborhood',
#  'reporting_area',
#  'reason_for_arrest',
#  'subdistrict',
#  'police_grid_number',
#  'use_of_force_reason',
#  'charged_speed',
#  'subdivision',
#  'substation']

# %%
options = {}
for col in columns:
    if col == 'officer_age':
        break
    val = lf.select(pl.col(col).unique()).collect()
    options[col] = val

# %%
start = False
for col in columns:
    if col == 'officer_age':
        start = True
    if start:
        val = lf.select(pl.col(col).unique()).collect()
        options[col] = val
options
# Out:
# {'date': shape: (8_034, 1)
#  ┌────────────┐
#  │ date       │
#  │ ---        │
#  │ date       │
#  ╞════════════╡
#  │ null       │
#  │ 1971-01-05 │
#  │ 1971-04-25 │
#  │ 1971-05-17 │
#  │ 1973-06-21 │
#  │ …          │
#  │ 2020-11-01 │
#  │ 2020-11-02 │
#  │ 2020-11-03 │
#  │ 2020-11-04 │
#  │ 2020-11-19 │
#  └────────────┘,
#  'time': shape: (86_401, 1)
#  ┌──────────┐
#  │ time     │
#  │ ---      │
#  │ str      │
#  ╞══════════╡
#  │ 18:23:07 │
#  │ 02:26:10 │
#  │ 12:54:17 │
#  │ 08:01:37 │
#  │ 18:22:58 │
#  │ …        │
#  │ 09:58:19 │
#  │ 17:21:26 │
#  │ 11:44:40 │
#  │ 14:58:00 │
#  │ 16:38:25 │
#  └──────────┘,
#  'location': shape: (5_889_523, 1)
#  ┌─────────────────────────────────┐
#  │ location                        │
#  │ ---                             │
#  │ str                             │
#  ╞═════════════════════════════════╡
#  │ I94 EB MM 227, NOT IN CITY LIM… │
#  │ DIAMOND near: JEFFERSON         │
#  │ MERCERVILLE RD                  │
#  │ VEIRS MILL RD AT FIRST ST       │
#  │ US-93 NB MM 80, NOT IN CITY LI… │
#  │ …                               │
#  │ 35 AV S / S ORCAS ST            │
#  │ HADLEY AVE & OLD HICKORY BLVD,… │
#  │ 926 N 3RD STCAMDEN, NJ 08102UN… │
#  │ FRONTAGE RD & MILL ST, Berlin   │
#  │ MM273 HWY 9                     │
#  └─────────────────────────────────┘,
#  'county_name': shape: (1_359, 1)
#  ┌────────────────────┐
#  │ county_name        │
#  │ ---                │
#  │ str                │
#  ╞════════════════════╡
#  │ Wexford County     │
#  │ Mecklenburg County │
#  │ Bartow County      │
#  │ Pinal County       │
#  │ Hillsdale County   │
#  │ …                  │
#  │ G223 County        │
#  │ Powell County      │
#  │ Asotin County      │
#  │ Brule County       │
#  │ Clearmont County   │
#  └────────────────────┘,
#  'subject_age': shape: (102, 1)
#  ┌─────────────┐
#  │ subject_age │
#  │ ---         │
#  │ str         │
#  ╞═════════════╡
#  │ 51          │
#  │ 81          │
#  │ 82          │
#  │ 38          │
#  │ 58          │
#  │ …           │
#  │ 64          │
#  │ 30          │
#  │ 93          │
#  │ 77          │
#  │ 41          │
#  └─────────────┘,
#  'subject_race': shape: (7, 1)
#  ┌────────────────────────┐
#  │ subject_race           │
#  │ ---                    │
#  │ str                    │
#  ╞════════════════════════╡
#  │ null                   │
#  │ hispanic               │
#  │ black                  │
#  │ other                  │
#  │ unknown                │
#  │ asian/pacific islander │
#  │ white                  │
#  └────────────────────────┘,
#  'subject_sex': shape: (3, 1)
#  ┌─────────────┐
#  │ subject_sex │
#  │ ---         │
#  │ str         │
#  ╞═════════════╡
#  │ female      │
#  │ null        │
#  │ male        │
#  └─────────────┘,
#  'officer_id_hash': shape: (2_145_432, 1)
#  ┌─────────────────┐
#  │ officer_id_hash │
#  │ ---             │
#  │ str             │
#  ╞═════════════════╡
#  │ 78c7f28f50      │
#  │ a0354a0f69      │
#  │ fa27b5f3cc      │
#  │ 3b5c82756a      │
#  │ 8f7d7172d2      │
#  │ …               │
#  │ ef99e07920      │
#  │ a7f4c2211b      │
#  │ acb77f19c0      │
#  │ cc117502ad      │
#  │ 4d5f049a62      │
#  └─────────────────┘,
#  'department_name': shape: (3_309, 1)
#  ┌─────────────────────────────────┐
#  │ department_name                 │
#  │ ---                             │
#  │ str                             │
#  ╞═════════════════════════════════╡
#  │ STMARYS                         │
#  │ KARNAK POLICE                   │
#  │ Sunrise Beach Police Dept.      │
#  │ Newton County Sheriff Office    │
#  │ Maggie Valley Police Departmen… │
#  │ …                               │
#  │ Albemarle Police Department     │
#  │ Noxubee County Sheriff Office   │
#  │ CALLAWAY P.D.                   │
#  │ TUSCOLA POLICE                  │
#  │ EFFINGHAM COUNTY SHERIFF        │
#  └─────────────────────────────────┘,
#  'type': shape: (3, 1)
#  ┌────────────┐
#  │ type       │
#  │ ---        │
#  │ str        │
#  ╞════════════╡
#  │ vehicular  │
#  │ pedestrian │
#  │ null       │
#  └────────────┘,
#  'arrest_made': shape: (3, 1)
#  ┌─────────────┐
#  │ arrest_made │
#  │ ---         │
#  │ str         │
#  ╞═════════════╡
#  │ FALSE       │
#  │ null        │
#  │ TRUE        │
#  └─────────────┘,
#  'citation_issued': shape: (3, 1)
#  ┌─────────────────┐
#  │ citation_issued │
#  │ ---             │
#  │ str             │
#  ╞═════════════════╡
#  │ TRUE            │
#  │ FALSE           │
#  │ null            │
#  └─────────────────┘,
#  'warning_issued': shape: (3, 1)
#  ┌────────────────┐
#  │ warning_issued │
#  │ ---            │
#  │ str            │
#  ╞════════════════╡
#  │ null           │
#  │ FALSE          │
#  │ TRUE           │
#  └────────────────┘,
#  'outcome': shape: (5, 1)
#  ┌──────────┐
#  │ outcome  │
#  │ ---      │
#  │ str      │
#  ╞══════════╡
#  │ citation │
#  │ arrest   │
#  │ summons  │
#  │ null     │
#  │ warning  │
#  └──────────┘,
#  'contraband_found': shape: (3, 1)
#  ┌──────────────────┐
#  │ contraband_found │
#  │ ---              │
#  │ str              │
#  ╞══════════════════╡
#  │ FALSE            │
#  │ null             │
#  │ TRUE             │
#  └──────────────────┘,
#  'contraband_drugs': shape: (3, 1)
#  ┌──────────────────┐
#  │ contraband_drugs │
#  │ ---              │
#  │ str              │
#  ╞══════════════════╡
#  │ null             │
#  │ TRUE             │
#  │ FALSE            │
#  └──────────────────┘,
#  'contraband_weapons': shape: (3, 1)
#  ┌────────────────────┐
#  │ contraband_weapons │
#  │ ---                │
#  │ str                │
#  ╞════════════════════╡
#  │ TRUE               │
#  │ FALSE              │
#  │ null               │
#  └────────────────────┘,
#  'frisk_performed': shape: (3, 1)
#  ┌─────────────────┐
#  │ frisk_performed │
#  │ ---             │
#  │ str             │
#  ╞═════════════════╡
#  │ null            │
#  │ FALSE           │
#  │ TRUE            │
#  └─────────────────┘,
#  'search_conducted': shape: (3, 1)
#  ┌──────────────────┐
#  │ search_conducted │
#  │ ---              │
#  │ str              │
#  ╞══════════════════╡
#  │ null             │
#  │ FALSE            │
#  │ TRUE             │
#  └──────────────────┘,
#  'search_person': shape: (3, 1)
#  ┌───────────────┐
#  │ search_person │
#  │ ---           │
#  │ str           │
#  ╞═══════════════╡
#  │ FALSE         │
#  │ null          │
#  │ TRUE          │
#  └───────────────┘,
#  'search_vehicle': shape: (3, 1)
#  ┌────────────────┐
#  │ search_vehicle │
#  │ ---            │
#  │ str            │
#  ╞════════════════╡
#  │ FALSE          │
#  │ null           │
#  │ TRUE           │
#  └────────────────┘,
#  'search_basis': shape: (6, 1)
#  ┌────────────────┐
#  │ search_basis   │
#  │ ---            │
#  │ str            │
#  ╞════════════════╡
#  │ other          │
#  │ null           │
#  │ consent        │
#  │ plain view     │
#  │ probable cause │
#  │ k9             │
#  └────────────────┘,
#  'reason_for_frisk': shape: (76, 1)
#  ┌─────────────────────────────────┐
#  │ reason_for_frisk                │
#  │ ---                             │
#  │ str                             │
#  ╞═════════════════════════════════╡
#  │ Erratic/Suspicious Behavior|Su… │
#  │ Erratic/Suspicious Behavior|Ob… │
#  │ Erratic/Suspicious Behavior|Ot… │
#  │ null                            │
#  │ Erratic/Suspicious Behavior|Su… │
#  │ …                               │
#  │ Erratic/Suspicious Behavior|Su… │
#  │ Other Official Information|Err… │
#  │ Observation of Suspected Contr… │
#  │ Suspicious Movement|Informant … │
#  │ Observation of Suspected Contr… │
#  └─────────────────────────────────┘,
#  'reason_for_search': shape: (1_196, 1)
#  ┌─────────────────────────────────┐
#  │ reason_for_search               │
#  │ ---                             │
#  │ str                             │
#  ╞═════════════════════════════════╡
#  │ Consent Search, PASSENGER RABB… │
#  │ Other, -----A VC/DRIVER NO SUF… │
#  │ Consent Search, VERBAL CONSENT… │
#  │ Probably Cause                  │
#  │ Reasonable Suspicion|Plain Vie… │
#  │ …                               │
#  │ Other, -----VC ID SEARCH        │
#  │ -th Waiver Search, INVENTORY    │
#  │ INC ARREST                      │
#  │ Odor of Drugs/Alcohol|Plain Vi… │
#  │ -th Waiver Search, PASSENGER -… │
#  └─────────────────────────────────┘,
#  'reason_for_stop': shape: (4_803, 1)
#  ┌─────────────────────────────────┐
#  │ reason_for_stop                 │
#  │ ---                             │
#  │ str                             │
#  ╞═════════════════════════════════╡
#  │ OPERATE SNOWMOBILE W/O SECURIN… │
#  │ --Z PASSENGER/LOAD INTERFERE W… │
#  │ LAMPS ON OTHER VEHS & EQUIP     │
#  │ *TRESPASS PRIVATE PROPERTY      │
#  │ TOWING VEHICLES REQUIREMENTS    │
#  │ …                               │
#  │ BARKING DOG                     │
#  │ DISORDERLY CONDUCT              │
#  │ -- --- -F                       │
#  │ Speed - (Freeway) ----- Over    │
#  │ CONT SUBST-POSSESSION OF MARIJ… │
#  └─────────────────────────────────┘,
#  'violation': shape: (1_052_647, 1)
#  ┌─────────────────────────────────┐
#  │ violation                       │
#  │ ---                             │
#  │ str                             │
#  ╞═════════════════════════════════╡
#  │ 321.285-B: SPEEDING 55 OR < (6… │
#  │ No/Improper Mud Flap|Defective… │
#  │ Disregard Red Light-traffic Si… │
#  │ INADEQUATE OR NO STOP LAMPS - … │
#  │ Oper Licence - I|DUI - Drugs W… │
#  │ …                               │
#  │ Fail To Pull To Right When Req… │
#  │ 321.381: TAILIGHT, EXHAUST      │
#  │ 321.285-G: SPEEDING R OPP NS 8… │
#  │ Driving While License Invalid … │
#  │ UNINSPECTED MOTOR VEHICLE    E… │
#  └─────────────────────────────────┘,
#  'vehicle_color': shape: (7_000, 1)
#  ┌───────────────┐
#  │ vehicle_color │
#  │ ---           │
#  │ str           │
#  ╞═══════════════╡
#  │ TAV           │
#  │ NC            │
#  │ GRY-SIL       │
#  │ BLAKC         │
#  │ SILVVER       │
#  │ …             │
#  │ BLK/GR        │
#  │ LINCOLN       │
#  │ BACK CHERRY   │
#  │ BLACK&ORANGE  │
#  │ PWETER        │
#  └───────────────┘,
#  'vehicle_make': shape: (101_583, 1)
#  ┌─────────────────┐
#  │ vehicle_make    │
#  │ ---             │
#  │ str             │
#  ╞═════════════════╡
#  │ CHILTON TRAILER │
#  │ Geo  Prizm      │
#  │ ki/tr           │
#  │ 13766 GREYHAWK  │
#  │ PRAGGIO         │
#  │ …               │
#  │ TOY COROLLA 10  │
#  │ olso            │
#  │ CHUC            │
#  │ KIA SUV 2011    │
#  │ NISS 4DR 2012   │
#  └─────────────────┘,
#  'vehicle_model': shape: (139_116, 1)
#  ┌──────────────────────┐
#  │ vehicle_model        │
#  │ ---                  │
#  │ str                  │
#  ╞══════════════════════╡
#  │ V6 LE                │
#  │ beretta              │
#  │ F-450 PICKUP         │
#  │ EPDT                 │
#  │ SPRINT St            │
#  │ …                    │
#  │ XLL                  │
#  │ INTURPID             │
#  │ X-RAIL               │
#  │ NLI1 82 AT 18SEP2009 │
#  │ GSX1300RZ            │
#  └──────────────────────┘,
#  'vehicle_registration_state': shape: (52, 1)
#  ┌────────────────────────────┐
#  │ vehicle_registration_state │
#  │ ---                        │
#  │ str                        │
#  ╞════════════════════════════╡
#  │ AZ                         │
#  │ ND                         │
#  │ WI                         │
#  │ CA                         │
#  │ ID                         │
#  │ …                          │
#  │ SD                         │
#  │ AK                         │
#  │ PA                         │
#  │ MS                         │
#  │ NM                         │
#  └────────────────────────────┘,
#  'vehicle_year': shape: (1_035, 1)
#  ┌──────────────┐
#  │ vehicle_year │
#  │ ---          │
#  │ str          │
#  ╞══════════════╡
#  │ 4213         │
#  │ 2820         │
#  │ 3863         │
#  │ 9000         │
#  │ 1919         │
#  │ …            │
#  │ 2996         │
#  │ 9924         │
#  │ 1883         │
#  │ 9259         │
#  │ 2004         │
#  └──────────────┘,
#  'service_area': shape: (92, 1)
#  ┌──────────────┐
#  │ service_area │
#  │ ---          │
#  │ str          │
#  ╞══════════════╡
#  │ 063          │
#  │ 251          │
#  │ 173          │
#  │ 392          │
#  │ 153          │
#  │ …            │
#  │ 320          │
#  │ 093          │
#  │ 610          │
#  │ 820          │
#  │ 141          │
#  └──────────────┘,
#  'officer_race': shape: (7, 1)
#  ┌────────────────────────┐
#  │ officer_race           │
#  │ ---                    │
#  │ str                    │
#  ╞════════════════════════╡
#  │ white                  │
#  │ asian/pacific islander │
#  │ unknown                │
#  │ hispanic               │
#  │ other                  │
#  │ null                   │
#  │ black                  │
#  └────────────────────────┘,
#  'lat': shape: (4_174_393, 1)
#  ┌────────────┐
#  │ lat        │
#  │ ---        │
#  │ f32        │
#  ╞════════════╡
#  │ null       │
#  │ -84.688942 │
#  │ -84.673225 │
#  │ -84.672722 │
#  │ -84.656181 │
#  │ …          │
#  │ 89.0       │
#  │ 89.98333   │
#  │ 89.999718  │
#  │ 441350.0   │
#  │ 443008.0   │
#  └────────────┘,
#  'lng': shape: (2_964_433, 1)
#  ┌─────────────┐
#  │ lng         │
#  │ ---         │
#  │ f32         │
#  ╞═════════════╡
#  │ null        │
#  │ -179.999985 │
#  │ -157.942276 │
#  │ -147.7659   │
#  │ -129.136978 │
#  │ …           │
#  │ 114.129402  │
#  │ 114.420158  │
#  │ 179.0       │
#  │ 874620.0    │
#  │ 880248.0    │
#  └─────────────┘,
#  'geocode_source': shape: (3, 1)
#  ┌────────────────┐
#  │ geocode_source │
#  │ ---            │
#  │ str            │
#  ╞════════════════╡
#  │ null           │
#  │ SU             │
#  │ GM             │
#  └────────────────┘,
#  'beat': shape: (59_853, 1)
#  ┌────────────┐
#  │ beat       │
#  │ ---        │
#  │ str        │
#  ╞════════════╡
#  │ 2533       │
#  │ RT34/WAUB  │
#  │ N300E2050  │
#  │ F.H.       │
#  │ 37 I66 ent │
#  │ …          │
#  │ 49/1400    │
#  │ Fishlakerd │
#  │ 1500 ILRt2 │
#  │ 2711       │
#  │ 3T06       │
#  └────────────┘,
#  'division': shape: (589, 1)
#  ┌──────────┐
#  │ division │
#  │ ---      │
#  │ str      │
#  ╞══════════╡
#  │ HQ       │
#  │ FMO      │
#  │ 227      │
#  │ GSP      │
#  │ HAN      │
#  │ …        │
#  │ 611      │
#  │ GIB      │
#  │ 15       │
#  │ OGT      │
#  │ SED      │
#  └──────────┘,
#  'officer_sex': shape: (3, 1)
#  ┌─────────────┐
#  │ officer_sex │
#  │ ---         │
#  │ str         │
#  ╞═════════════╡
#  │ null        │
#  │ male        │
#  │ female      │
#  └─────────────┘,
#  'disposition': shape: (2_041, 1)
#  ┌─────────────────────────────────┐
#  │ disposition                     │
#  │ ---                             │
#  │ str                             │
#  ╞═════════════════════════════════╡
#  │ incident report                 │
#  │ GUILTY; DISMISSED; GUILTY; DIS… │
#  │ DISMISSED; ; DISMISSED;         │
#  │ Party Advised,T - Citation Iss  │
#  │ PROVIDED PROOF; AMENDED CHARGE… │
#  │ …                               │
#  │ GUILTY; GUILTY; GUILTY; GUILTY  │
#  │ DISMISSED; GUILTY; DISMISSED; … │
#  │ NOLLE PROS; GUILTY; GUILTY      │
#  │ DISMISSED; NOLLO CONTENDRE      │
#  │ HAD DRIVERS LICENSE; GUILTY; G… │
#  └─────────────────────────────────┘,
#  'posted_speed': shape: (157, 1)
#  ┌──────────────┐
#  │ posted_speed │
#  │ ---          │
#  │ str          │
#  ╞══════════════╡
#  │ 71           │
#  │ 74           │
#  │ 47           │
#  │ 51           │
#  │ 82           │
#  │ …            │
#  │ 1            │
#  │ 70           │
#  │ 33           │
#  │ 76           │
#  │ 103          │
#  └──────────────┘,
#  'district': shape: (2_267, 1)
#  ┌──────────┐
#  │ district │
#  │ ---      │
#  │ str      │
#  ╞══════════╡
#  │ 361      │
#  │ 461      │
#  │ 126      │
#  │ 1252     │
#  │ 0563     │
#  │ …        │
#  │ 0429     │
#  │ 0838     │
#  │ 0399     │
#  │ 0889     │
#  │ 1322     │
#  └──────────┘,
#  'precinct': shape: (146, 1)
#  ┌──────────┐
#  │ precinct │
#  │ ---      │
#  │ str      │
#  ╞══════════╡
#  │ C        │
#  │ 48       │
#  │ 523      │
#  │ 5        │
#  │ 0        │
#  │ …        │
#  │ 46       │
#  │ 74       │
#  │ 94       │
#  │ 25       │
#  │ 38       │
#  └──────────┘,
#  'speed': shape: (335, 1)
#  ┌───────┐
#  │ speed │
#  │ ---   │
#  │ str   │
#  ╞═══════╡
#  │ 148   │
#  │ 128   │
#  │ 149   │
#  │ 500   │
#  │ 851   │
#  │ …     │
#  │ 563   │
#  │ 144   │
#  │ 28    │
#  │ 817   │
#  │ 857   │
#  └───────┘,
#  'contraband_other': shape: (3, 1)
#  ┌──────────────────┐
#  │ contraband_other │
#  │ ---              │
#  │ str              │
#  ╞══════════════════╡
#  │ TRUE             │
#  │ null             │
#  │ FALSE            │
#  └──────────────────┘,
#  'vehicle_type': shape: (1_593, 1)
#  ┌──────────────────────┐
#  │ vehicle_type         │
#  │ ---                  │
#  │ str                  │
#  ╞══════════════════════╡
#  │ PRELUDE S            │
#  │ SEDA                 │
#  │ RF3                  │
#  │ OFF-ROAD             │
#  │ SRT4                 │
#  │ …                    │
#  │ GRAND CARA           │
#  │ XST Style            │
#  │ Sedan 5 Door - Not A │
#  │ NAV Style            │
#  │ MOU Style            │
#  └──────────────────────┘,
#  'officer_age': shape: (70, 1)
#  ┌─────────────┐
#  │ officer_age │
#  │ ---         │
#  │ str         │
#  ╞═════════════╡
#  │ 79          │
#  │ 78          │
#  │ 39          │
#  │ 14          │
#  │ 55          │
#  │ …           │
#  │ 69          │
#  │ 60          │
#  │ 71          │
#  │ 65          │
#  │ 46          │
#  └─────────────┘,
#  'officer_years_of_service': shape: (105, 1)
#  ┌──────────────────────────┐
#  │ officer_years_of_service │
#  │ ---                      │
#  │ str                      │
#  ╞══════════════════════════╡
#  │ -3                       │
#  │ 7                        │
#  │ 17                       │
#  │ 23                       │
#  │ 18                       │
#  │ …                        │
#  │ -69                      │
#  │ 48                       │
#  │ -8                       │
#  │ -68                      │
#  │ 29                       │
#  └──────────────────────────┘,
#  'unit': shape: (709, 1)
#  ┌────────────┐
#  │ unit       │
#  │ ---        │
#  │ str        │
#  ╞════════════╡
#  │ FHPT\FHP T │
#  │ 140        │
#  │ NORTH      │
#  │ w45        │
#  │ W25        │
#  │ …          │
#  │ 976        │
#  │ E47        │
#  │ 538        │
#  │ W80        │
#  │ 161        │
#  └────────────┘,
#  'notes': shape: (181_327, 1)
#  ┌─────────────────────────────────┐
#  │ notes                           │
#  │ ---                             │
#  │ str                             │
#  ╞═════════════════════════════════╡
#  │ -- in a-- mph zone              │
#  │ TRAFFIC STOP IN REFERENCE TO C… │
#  │ WINDOW TINT APPEARED TO BE OUT… │
#  │ STOP FOR EXPIRED TAG. REVOKED.… │
#  │ dirt bike on street             │
#  │ …                               │
#  │ -WF RL- TO CL- TO NO EMERGENCY… │
#  │ TEMP TAG BEHIND TINTED GLASS    │
#  │                                 │
#  │ MIDDLE LANE GOING OBIVIOUSLY F… │
#  │ DRIVING WITH ONLY PARKING LIGH… │
#  │ SPEEDING (-- MPH IN A -- MPH Z… │
#  └─────────────────────────────────┘,
#  'sector': shape: (183, 1)
#  ┌────────┐
#  │ sector │
#  │ ---    │
#  │ str    │
#  ╞════════╡
#  │ 632    │
#  │ BRAVO  │
#  │ 627    │
#  │ Z      │
#  │ Y      │
#  │ …      │
#  │ SF2    │
#  │ X      │
#  │ 619    │
#  │ 518    │
#  │ PM     │
#  └────────┘,
#  'subsector': shape: (5, 1)
#  ┌───────────┐
#  │ subsector │
#  │ ---       │
#  │ str       │
#  ╞═══════════╡
#  │ 4         │
#  │ null      │
#  │ 3         │
#  │ 2         │
#  │ 1         │
#  └───────────┘,
#  'officer_assignment': shape: (83, 1)
#  ┌───────────────────────────────┐
#  │ officer_assignment            │
#  │ ---                           │
#  │ str                           │
#  ╞═══════════════════════════════╡
#  │ INTELLIGENCE                  │
#  │ DARE SQUAD                    │
#  │ PERSONAL CRIMES UNIT          │
#  │ Other                         │
#  │ TRAFFIC UNIT                  │
#  │ …                             │
#  │ DISTRICT 2 INVESTIGATIVE UNIT │
#  │ FIREARMS TRAINING UNIT        │
#  │ CPOP LIAISON UNIT             │
#  │ SRO SQUAD                     │
#  │ DISTRICT 4 INVESTIGATIVE UNIT │
#  └───────────────────────────────┘,
#  'use_of_force_description': shape: (4, 1)
#  ┌─────────────────────────────────┐
#  │ use_of_force_description        │
#  │ ---                             │
#  │ str                             │
#  ╞═════════════════════════════════╡
#  │ no curb, no handcuff, no polic… │
#  │ handcuffed                      │
#  │ sat in police vehicle           │
#  │ null                            │
#  └─────────────────────────────────┘,
#  'department_id': shape: (1_690, 1)
#  ┌───────────────┐
#  │ department_id │
#  │ ---           │
#  │ str           │
#  ╞═══════════════╡
#  │ 14139         │
#  │ 13723         │
#  │ 13679         │
#  │ 13704         │
#  │ 13159         │
#  │ …             │
#  │ 1101          │
#  │ 13016         │
#  │ 9021          │
#  │ 13923         │
#  │ 13137         │
#  └───────────────┘,
#  'contraband_alcohol': shape: (3, 1)
#  ┌────────────────────┐
#  │ contraband_alcohol │
#  │ ---                │
#  │ str                │
#  ╞════════════════════╡
#  │ FALSE              │
#  │ null               │
#  │ TRUE               │
#  └────────────────────┘,
#  'zone': shape: (127, 1)
#  ┌──────┐
#  │ zone │
#  │ ---  │
#  │ str  │
#  ╞══════╡
#  │ BING │
#  │ 111  │
#  │ J    │
#  │ O    │
#  │ 225  │
#  │ …    │
#  │ R    │
#  │ 613  │
#  │ 333  │
#  │ X4   │
#  │ 335  │
#  └──────┘,
#  'region': shape: (89, 1)
#  ┌─────────────────────┐
#  │ region              │
#  │ ---                 │
#  │ str                 │
#  ╞═════════════════════╡
#  │ ROBBERY/HOMICIDE    │
#  │ DET SUPPORT         │
#  │ 1                   │
#  │ AIR SUPPORT         │
#  │ SOUTHCOAST          │
#  │ …                   │
#  │ TOPANGA             │
#  │ GENERAL SERV POLICE │
#  │ NORTHEAST           │
#  │ VALLEY TRAFFIC      │
#  │ COMMISSION INVESTIG │
#  └─────────────────────┘,
#  'neighborhood': shape: (75, 1)
#  ┌────────────────────────────────┐
#  │ neighborhood                   │
#  │ ---                            │
#  │ str                            │
#  ╞════════════════════════════════╡
#  │ LAW                            │
#  │ ROSELAWN                       │
#  │ SOUTH                          │
#  │ COLUMBIA TUSCULUM              │
#  │ CAMP WASHINGTON                │
#  │ …                              │
#  │ SPRING GROVE VILLAGE           │
#  │ GRNB_W                         │
#  │ MT. LOOKOUT                    │
#  │ NORTH AVONDALE - PADDOCK HILLS │
#  │ MT. AIRY                       │
#  └────────────────────────────────┘,
#  'reporting_area': shape: (2_037, 1)
#  ┌────────────────┐
#  │ reporting_area │
#  │ ---            │
#  │ str            │
#  ╞════════════════╡
#  │ 9617           │
#  │ 1590           │
#  │ 9535           │
#  │ 4233           │
#  │ 5201           │
#  │ …              │
#  │ 5301           │
#  │ 4211           │
#  │ 6603           │
#  │ 1841           │
#  │ 1223           │
#  └────────────────┘,
#  'reason_for_arrest': shape: (116, 1)
#  ┌──────────────────────────────┐
#  │ reason_for_arrest            │
#  │ ---                          │
#  │ str                          │
#  ╞══════════════════════════════╡
#  │ Based on Stop                │
#  │ ------H                      │
#  │ Auto Theft                   │
#  │ ------.C                     │
#  │ s                            │
#  │ …                            │
#  │ Driving on suspended license │
#  │ ------B                      │
#  │ ------(A)(-)                 │
#  │ POSS CDS                     │
#  │ ------C-                     │
#  └──────────────────────────────┘,
#  'subdistrict': shape: (11, 1)
#  ┌─────────────┐
#  │ subdistrict │
#  │ ---         │
#  │ str         │
#  ╞═════════════╡
#  │ 9           │
#  │ 1           │
#  │ 2           │
#  │ 4           │
#  │ 8           │
#  │ …           │
#  │ 6           │
#  │ 5           │
#  │ 0           │
#  │ null        │
#  │ 3           │
#  └─────────────┘,
#  'police_grid_number': shape: (204, 1)
#  ┌────────────────────┐
#  │ police_grid_number │
#  │ ---                │
#  │ str                │
#  ╞════════════════════╡
#  │ 2                  │
#  │ 194                │
#  │ 27                 │
#  │ 187                │
#  │ 125                │
#  │ …                  │
#  │ 84                 │
#  │ 214                │
#  │ 131                │
#  │ 242                │
#  │ 49                 │
#  └────────────────────┘,
#  'use_of_force_reason': shape: (7, 1)
#  ┌─────────────────────────────────┐
#  │ use_of_force_reason             │
#  │ ---                             │
#  │ str                             │
#  ╞═════════════════════════════════╡
#  │ null                            │
#  │ medical condition               │
#  │ weapons / violence related eve… │
#  │ officer safety concerns         │
#  │ no curb, no handcuff, no polic… │
#  │ safety concern during prior co… │
#  │ other                           │
#  └─────────────────────────────────┘,
#  'charged_speed': shape: (131, 1)
#  ┌───────────────┐
#  │ charged_speed │
#  │ ---           │
#  │ str           │
#  ╞═══════════════╡
#  │ 115           │
#  │ 126           │
#  │ 135           │
#  │ 57            │
#  │ 56            │
#  │ …             │
#  │ 129           │
#  │ 40            │
#  │ 80            │
#  │ 95            │
#  │ 7             │
#  └───────────────┘,
#  'subdivision': shape: (216, 1)
#  ┌─────────────┐
#  │ subdivision │
#  │ ---         │
#  │ str         │
#  ╞═════════════╡
#  │ 96          │
#  │ 86          │
#  │ 39          │
#  │ 144         │
#  │ 178         │
#  │ …           │
#  │ 117         │
#  │ 64          │
#  │ 31          │
#  │ 176         │
#  │ 79          │
#  └─────────────┘,
#  'substation': shape: (7, 1)
#  ┌────────────┐
#  │ substation │
#  │ ---        │
#  │ str        │
#  ╞════════════╡
#  │ WEST       │
#  │ NORTH      │
#  │ SOUTH      │
#  │ EAST       │
#  │ CENTRAL    │
#  │ null       │
#  │ PRUE       │
#  └────────────┘}

# %%
clean = lf.drop_nulls()
clean.limit(50).collect()
# Out:
# shape: (0, 67)
# ┌──────┬──────┬──────────┬─────────────┬───┬──────────────┬─────────────┬─────────────┬────────────┐
# │ date ┆ time ┆ location ┆ county_name ┆ … ┆ use_of_force ┆ charged_spe ┆ subdivision ┆ substation │
# │ ---  ┆ ---  ┆ ---      ┆ ---         ┆   ┆ _reason      ┆ ed          ┆ ---         ┆ ---        │
# │ date ┆ str  ┆ str      ┆ str         ┆   ┆ ---          ┆ ---         ┆ str         ┆ str        │
# │      ┆      ┆          ┆             ┆   ┆ str          ┆ str         ┆             ┆            │
# ╞══════╪══════╪══════════╪═════════════╪═══╪══════════════╪═════════════╪═════════════╪════════════╡
# └──────┴──────┴──────────┴─────────────┴───┴──────────────┴─────────────┴─────────────┴────────────┘
